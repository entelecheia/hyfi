# %% [markdown]
# # Examples
#
# This page contains a few examples of how you can use HyFI: Hydra Fast Interface package.
#
# ## Installation
#
# You can install HyFI: Hydra Fast Interface using `pip`:

# %%
pip install hyfi
# Out:
# Collecting hyfi
#   Downloading hyfi-0.2.1-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 2.5 MB/s eta 0:00:00
# Collecting chardet<6.0.0,>=5.1.0
#   Downloading chardet-5.1.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 20.2 MB/s eta 0:00:00
# Collecting gdown<5.0.0,>=4.6.4
#   Downloading gdown-4.6.4-py3-none-any.whl (14 kB)
# Collecting hydra-colorlog<2.0.0,>=1.2.0
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Collecting hydra-core<2.0.0,>=1.3.2
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 54.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.0 in /opt/hostedtoolcache/Python/3.11.2/x64/lib/python3.11/site-packages (from hyfi) (3.7.0)
# Collecting numpy<1.24
#   Downloading numpy-1.23.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/17.1 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 7.9/17.1 MB 236.1 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 17.0/17.1 MB 214.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 115.2 MB/s eta 0:00:00
# Collecting pandas<1.4.0
#   Downloading pandas-1.3.5.tar.gz (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/4.7 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 148.4 MB/s eta 0:00:00
#   Installing build dependencies ... -
# \
# |
# /
# -
# \
# |
# done
#   Getting requirements to build wheel ... -
# ^C
# canceled
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Usage
#
# ```python
# from hyfi import get_version
#
# print(get_version())
# ```
