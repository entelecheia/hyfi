# %% [markdown]
# # Examples
#
# This page contains a few examples of how you can use HyFI: Hydra Fast Interface package.
#
# ## Installation
#
# You can install HyFI: Hydra Fast Interface using `pip`:

# %%
pip install hyfi
# Out:
# ERROR: Could not find a version that satisfies the requirement hyfi (from versions: none)
# ERROR: No matching distribution found for hyfi
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Usage
#
# ```python
# from hyfi import get_version
#
# print(get_version())
# ```
